# %%
# !git clone https://github.com/skynbe/FedRCL

# %%
# %cd FedRCL

# %%
# !ls

# %%
# !pip install torch torchvision numpy pyyaml hydra-core

# %%
# import os
# import subprocess

# # Create the data directory
# os.makedirs("data", exist_ok=True)

# # Download & Extract CIFAR-10
# subprocess.run(["wget", "-O", "data/cifar-10-python.tar.gz", "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"])
# subprocess.run(["tar", "-xvzf", "data/cifar-10-python.tar.gz", "-C", "data/"])

# # Download & Extract CIFAR-100
# subprocess.run(["wget", "-O", "data/cifar-100-python.tar.gz", "https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz"])
# subprocess.run(["tar", "-xvzf", "data/cifar-100-python.tar.gz", "-C", "data/"])

# # Download & Extract Tiny-ImageNet
# subprocess.run(["wget", "-O", "data/tiny-imagenet-200.zip", "http://cs231n.stanford.edu/tiny-imagenet-200.zip"])
# subprocess.run(["unzip", "-q", "data/tiny-imagenet-200.zip", "-d", "data/"])

# %%
# import os

# # List the extracted dataset directory
# print(os.listdir("data"))

# %%
# !pip install torch torchvision torchaudio numpy pandas scipy scikit-learn matplotlib pyyaml wandb torchinfo torchmetrics umap umap-learn netcal

# %%
# pip install coloredlogs

# %%
# !pip install tensorflow

# %%
# # Uninstall current PyTorch
# !pip uninstall torch torchvision torchaudio -y

# # Install the compatible PyTorch version (replace with the exact version fastai needs)
# !pip install torch==1.13.1+cu117 torchvision==0.14.1+cu117 torchaudio==0.13.1+cu117 --index-url https://download.pytorch.org/whl/cu117

# # Reinstall fastai
# !pip install fastai==2.7.18

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121  # Try this first
# # If the above fails try this:
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# %%
# !pip install --upgrade fastai

# %%
import os
os.environ["XLA_FLAGS"] = "--xla_gpu_cuda_data_dir=/usr/lib/cuda"
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"  # Suppress CUDA warnings
os.environ["CUDA_VISIBLE_DEVICES"] = "0"  # Ensure only one GPU is used
# Out:
# PyTorch version: 2.5.1+cu124
# torchvision version: 0.20.1+cu124
# fastai version: 2.7.18
# CUDA is available: True

# %%
# !pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# ...
#   Using cached gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# ...
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# ...
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# ...
#   Using cached termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# ...
#   Using cached tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached keras-3.8.0-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached numpy-2.0.2-cp39-cp39-win_amd64.whl.metadata (59 kB)
# ...
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# ...

# %%
pip install --upgrade setuptools pip
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
#   Using cached setuptools-75.8.0-py3-none-any.whl.metadata (6.7 kB)
# ...
# Using cached setuptools-75.8.0-py3-none-any.whl (1.2 MB)
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 1.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.0/1.8 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.6/1.8 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 1.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
# ...

# %%
# import os
# import requests
# import zipfile
# import tarfile

# # Define dataset directory
# DATA_DIR = os.path.join(os.getcwd(), "data")
# os.makedirs(DATA_DIR, exist_ok=True)

# # Function to download files
# def download_file(url, output_path):
#     if not os.path.exists(output_path):  # Avoid re-downloading
#         print(f"Downloading {url} ...")
#         response = requests.get(url, stream=True)
#         with open(output_path, "wb") as file:
#             for chunk in response.iter_content(chunk_size=1024):
#                 file.write(chunk)
#         print(f"Saved to {output_path}")
#     else:
#         print(f"{output_path} already exists. Skipping download.")

# # Function to extract files
# def extract_file(filepath, extract_to):
#     if not os.path.exists(extract_to):
#         print(f"Extracting {filepath} ...")
#         if filepath.endswith(".tar.gz"):
#             with tarfile.open(filepath, "r:gz") as tar:
#                 tar.extractall(extract_to)
#         elif filepath.endswith(".zip"):
#             with zipfile.ZipFile(filepath, "r") as zip_ref:
#                 zip_ref.extractall(extract_to)
#         print(f"Extracted to {extract_to}")
#     else:
#         print(f"{extract_to} already exists. Skipping extraction.")

# # Download & Extract CIFAR-10
# cifar10_tar = os.path.join(DATA_DIR, "cifar-10-python.tar.gz")
# cifar10_extract = os.path.join(DATA_DIR, "cifar-10-batches-py")
# download_file("https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz", cifar10_tar)
# extract_file(cifar10_tar, DATA_DIR)

# # Download & Extract CIFAR-100
# cifar100_tar = os.path.join(DATA_DIR, "cifar-100-python.tar.gz")
# cifar100_extract = os.path.join(DATA_DIR, "cifar-100-python")
# download_file("https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz", cifar100_tar)
# extract_file(cifar100_tar, DATA_DIR)

# # Download & Extract Tiny-ImageNet
# tiny_imagenet_zip = os.path.join(DATA_DIR, "tiny-imagenet-200.zip")
# tiny_imagenet_extract = os.path.join(DATA_DIR, "tiny-imagenet-200")
# download_file("http://cs231n.stanford.edu/tiny-imagenet-200.zip", tiny_imagenet_zip)
# extract_file(tiny_imagenet_zip, DATA_DIR)

# print("Datasets downloaded and extracted successfully!")
# Out:
# ...
# Saved to c:\Users\ACER\Downloads\FedRCL-main\FedRCL-main\data\cifar-10-python.tar.gz
# c:\Users\ACER\Downloads\FedRCL-main\FedRCL-main\data already exists. Skipping extraction.
# ...
# Saved to c:\Users\ACER\Downloads\FedRCL-main\FedRCL-main\data\cifar-100-python.tar.gz
# c:\Users\ACER\Downloads\FedRCL-main\FedRCL-main\data already exists. Skipping extraction.
# ...
# Saved to c:\Users\ACER\Downloads\FedRCL-main\FedRCL-main\data\tiny-imagenet-200.zip
# c:\Users\ACER\Downloads\FedRCL-main\FedRCL-main\data already exists. Skipping extraction.
# Datasets downloaded and extracted successfully!

# %%
pip install numpy<2
# Out:
#   Cell In[41], line 1
#     pip install numpy<2
#         ^
# SyntaxError: invalid syntax

# %%
# !python federated_train.py client=fedrcl dataset=cifar10 trainer.num_clients=100 trainer.participation_rate=0.05 split.alpha=0.3
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "c:\Users\ACER\Downloads\FedRCL-main\FedRCL-main\federated_train.py", line 9, in <module>
#     from datasets.build import build_dataset, build_datasets
#   File "c:\Users\ACER\Downloads\FedRCL-main\FedRCL-main\datasets\__init__.py", line 2, in <module>
#     from .tiny_imagenet import *
#   File "c:\Users\ACER\Downloads\FedRCL-main\FedRCL-main\datasets\tiny_imagenet.py", line 14, in <module>
#     from datasets.base import *
# ...
